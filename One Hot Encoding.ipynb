# %% [markdown]
# # One Hot Encoding

# %% [markdown]
# ### This notebook goes through how to implement one hot encoding to deal with categorical data

# %%
# import packages
import numpy as np
import pandas as pd
import seaborn as sn

# %%
# read in the data set
data = pd.read_csv('data1.csv')
data
# Out:
#              Date Marital_Status
# 0      29/05/2020              M
# 1      03/07/2019              S
# 2      04/10/2019              M
# 3      22/09/2020              S
# 4      08/09/2019              M
# ...           ...            ...
# 49995  21/08/2020              M
# 49996  19/10/2019              M
# 49997  23/01/2019              D
# 49998  03/10/2020              M
# 49999  27/05/2020              S
#
# [50000 rows x 2 columns]

# %% [markdown]
# ### We can see that marital status is given as Married (M), Single (S) and Divorced (D)

# %%
# count plot
sn.countplot(x='Marital_Status', data=data)

# %% [markdown]
# ### If this was a classification problem we need to apply a model such as logistic regression. However, we need the marital status to be numerical data so the model can take it into account. We can map the categories to numerical values. This is called one hot encoding and expands the Marital Status column to three other columns and assigns binary values.for where 1 = True and 0 = False depending on the example. The code below will explain and visualise this better.

# %%
# create the dummies
dum = pd.get_dummies(data['Marital_Status'])
dum
# Out:
#        D  M  S
# 0      0  1  0
# 1      0  0  1
# 2      0  1  0
# 3      0  0  1
# 4      0  1  0
# ...   .. .. ..
# 49995  0  1  0
# 49996  0  1  0
# 49997  1  0  0
# 49998  0  1  0
# 49999  0  0  1
#
# [50000 rows x 3 columns]

# %%
# combine the data
data = pd.concat([data,dum], axis='columns')
data
# Out:
#              Date Marital_Status  D  M  S
# 0      29/05/2020              M  0  1  0
# 1      03/07/2019              S  0  0  1
# 2      04/10/2019              M  0  1  0
# 3      22/09/2020              S  0  0  1
# 4      08/09/2019              M  0  1  0
# ...           ...            ... .. .. ..
# 49995  21/08/2020              M  0  1  0
# 49996  19/10/2019              M  0  1  0
# 49997  23/01/2019              D  1  0  0
# 49998  03/10/2020              M  0  1  0
# 49999  27/05/2020              S  0  0  1
#
# [50000 rows x 5 columns]

# %%
# delete the unecessary column
del data['Marital_Status']
data
# Out:
#              Date  D  M  S
# 0      29/05/2020  0  1  0
# 1      03/07/2019  0  0  1
# 2      04/10/2019  0  1  0
# 3      22/09/2020  0  0  1
# 4      08/09/2019  0  1  0
# ...           ... .. .. ..
# 49995  21/08/2020  0  1  0
# 49996  19/10/2019  0  1  0
# 49997  23/01/2019  1  0  0
# 49998  03/10/2020  0  1  0
# 49999  27/05/2020  0  0  1
#
# [50000 rows x 4 columns]

# %% [markdown]
# ### And there we are! We have just one encoded the data so it can be used in classification models.
